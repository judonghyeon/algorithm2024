# %% [markdown]
# # [6.1 기수 정렬]
#
# ## 김민상
#
# ### 1) 문제 정의 (MD)
#
# 문제 이름 : 기수 정렬
#
# 문제 설명 : 주어진 리스트를 기수 정렬 방법으로 정렬해야 함.
#
# 문제 예시 : [28, 93, 39, 81, 62, 72, 38, 26]이 주어지면 [26, 28, 38, 39, 62, 72, 81, 93]이 반환되어야 함.
#
# ### 2) 알고리즘 설명  (MD)
#
# 리스트를 작은 자리 부터 시작해 분류하고, 큰 자리로 올라가며 정렬한다.
#
# ### 3) 손으로 푼 예제 (MD, 이미지 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4) 알고리즘 코드 개요(입력 변수, 출력, 알고리즘 개요) (MD)
#
# 함수 이름 : radix_sort(A)
#
# 매개변수 : 리스트 A
#
# 출력 : 정렬된 리스트 A
#
# 수행 순서 :
# 1. 큐에 작은 자리부터 n의자리까지 넣고 빼는 과정을 반복해서 리스트를 정렬한다.
#
# ### 5) 알고리즘 코드 (PY,C)

# %%
from queue import Queue
def radix_sort(A) :
    queues = []
    for i in range(BUCKETS) :
        queues.append(Queue())
        
    n = len(A)
    factor = 1
    for d in range(DIGITS) :
        for i in range(n) :
            queues[(A[i] // factor) % BUCKETS].put(A[i])
        j = 0
        for b in range(BUCKETS) :
            while not queues[b].empty() :
                A[j] = queues[b].get()
                j += 1
        factor *= BUCKETS
        print("step", d+1, A)

# %% [markdown]
# ###   6) 테스트 코드  (PY,C) , 입력을 바꾸어서

# %%
import random
BUCKETS = 10
DIGITS = 4
data = []
for i in range(10) :
    data.append(random.randint(1, 9999))
radix_sort(data)
print("radix: ", data)
# Out:
# step 1 [2211, 711, 5332, 3764, 3535, 6485, 9426, 5508, 9028, 9199]
# step 2 [5508, 2211, 711, 9426, 9028, 5332, 3535, 3764, 6485, 9199]
# step 3 [9028, 9199, 2211, 5332, 9426, 6485, 5508, 3535, 711, 3764]
# step 4 [711, 2211, 3535, 3764, 5332, 5508, 6485, 9028, 9199, 9426]
# radix:  [711, 2211, 3535, 3764, 5332, 5508, 6485, 9028, 9199, 9426]

# %% [markdown]
# ###  7) 수행 결과 (MD, 결과 캡춰하여 이미지로 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8) 복잡도 분석
#
# 정렬하는 수의 자릿수에 비례하여 O(dn)
#
# ###  9) 조별 협력 내용 (상호 지도)
#
# 각자 해결 후 질문사항 상호 지도
