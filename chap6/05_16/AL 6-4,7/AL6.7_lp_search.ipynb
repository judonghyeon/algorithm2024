# %% [markdown]
# #### 1.문제 정의
# 선형 조사법의 탐색 알고리즘

# %% [markdown]
# #### 2. 알고리즘 설명
# 탐색키가 입력되면 해시주소를 계산하고, 해당 주소에 같은 레코드가 있으면 탐색 성공, 없으면 다음 버킷을 검사. 이는 해당키의 레코드를 찾거나, 레코드가 없는 버킷을 만나거나 모든 버킷을 다 검사할 때 까지 진행

# %% [markdown]
# #### 3. 손으로 푼 예제
# ![AL6.7_lp_serch_h.png.jpg](attachment:AL6.7_lp_serch_h.png.jpg)

# %% [markdown]
# #### 4. 코드 개요
#
# 함수명: lp_serach(key) :
#
# 매개변수 M =13 테이블 크기
#
# 출력
# None = 찾는 항목이 테이블에 없음
# key = 찾는 항목이 테이블에 있으면 key값

# %% [markdown]
# #### 5. 코드

# %%
def lp_search(key):
    id=hasFn(key)
    count =M
    while count>0:
        if table[id]==None:
            return None
        if table[id]==key:
            return table[id]
        id = (id+1+M)% M 
        count -=1
    return None

# %% [markdown]
# #### 6. 테스트 코드

# %%
M =13
table = [None]*M
def hashFn(key):
    return key%M

def lp_insert(key):
    id=hashFn(key)
    count =M
    while count>0 and (table[id]!=None):
        id =(id+1+M)%M
        count -=1
    if count >0:
        table[id]=key
    return

def lp_search(key):
    id=hashFn(key)
    count =M
    while count>0:
        if table[id]==None:
            return None
        if table[id]==key:
            return table[id]
        id = (id+1+M)% M 
        count -=1
    return None

print("   최초",table)
lp_insert(45); print("45 삽입:",table)
lp_insert(27); print("27 삽입:",table)
lp_insert(88); print("88 삽입:",table)
lp_insert(9); print("9 삽입:",table)
print("46 탐색:",lp_search(46))
# Out:
#    최초 [None, None, None, None, None, None, None, None, None, None, None, None, None]
# 45 삽입: [None, None, None, None, None, None, 45, None, None, None, None, None, None]
# 27 삽입: [None, 27, None, None, None, None, 45, None, None, None, None, None, None]
# 88 삽입: [None, 27, None, None, None, None, 45, None, None, None, 88, None, None]
# 9 삽입: [None, 27, None, None, None, None, 45, None, None, 9, 88, None, None]
# 46 탐색: None

# %% [markdown]
# #### 7.수행 결과
# ![AL6.7_lp_serch.png](attachment:AL6.7_lp_serch.png)

# %% [markdown]
# #### 8. 복잡도 분석
# 충돌이 전혀 일어나지 않는 최선의 경우 O(1)
# 최악의 경우 O(n)
